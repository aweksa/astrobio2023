# %% [markdown]
# ![exo_4200x3000px.png](attachment:2576133f-b3d3-410b-9359-192ec0429e14.png)

# %% [markdown]
# Sa slike kumulativne verovatnoce perioda, mozemo da primetimo da vise od 90% planeta upada u opset od 0 do 2500 dana.

# %% [markdown]
# ![exo_4200x3000px (copy 1).png](attachment:a78c36de-659b-4aea-840f-bd6468ef407e.png)

# %% [markdown]
# Mozemo da primetimo da je oko 90% na opsegu od -11325 do 0

# %% [markdown]
# ![exo_4200x3000px (copy 2).png](attachment:6b48b2a9-2290-4c53-a826-01d3c2d6b93e.png)

# %% [markdown]
# What is, roughly, the fraction of planets with orbital eccentricity greater 0.1?
#
# 0.7
#
# What about greater than 0.5?
#
# 0.1
